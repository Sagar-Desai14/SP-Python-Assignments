# %% [markdown]
# # Basic Operations on DataTypes
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. String -(Immutable)

# %%
"""
1.capitalize            It converts first letter to uppercase
2.upper                 Converts all characters to uppercase.
3.lower                 Converts all characters to lowercase.
4.title                 Converts the first character of each word to uppercase.
5.count                 Returns the number of non-overlapping occurrences of the substring. 
6.casefold              Aggressive lowercase conversion for case-insensitive matching (stronger than lower()).#पण हे फक्त इंग्रजीत नाही—जगातील जवळपास सगळ्या भाषांचे खास अक्षरंही नीट convert करते.
7.endwith               Checks if the string ends with the specified suffix.
8.startwith             Checks if the string starts with the specified prefix.
9.find                  Returns the lowest index of the substring; returns -1 if not found.
10.index                Returns the lowest index of the substring; raises a ValueError if not found.
11.isalnum              Checks if all characters are alphanumeric (letters or numbers), and the string is not empty.
12.isalpha              Checks if all characters are alphabetic (letters), and the string is not empty.
13.Swapcase             Swaps the case of every letter (uppercase to lowercase, and vice-versa).
14.strip                Returns a copy of the string with leading and trailing whitespace removed.
15.islower              Checks if all cased characters are lowercase.
16.isupper              Checks if all cased characters are uppercase.
17.replace              Returns a copy with all occurrences of old substring replaced by new.
18.split                Splits the string by whitespace (default) and returns a list of strings.
19.partition            Splits the string at the first occurrence of the separator, returning a 3-tuple.   
20.__contain__          Implements the in operator (checks if substring exists).
21.__size of__          Returns the size of the string object in memory (in bytes).
22.__len__              Implements the len() function (returns the length of the string).
23.removeprefix         Removes the prefix if the string starts with it.  
24.removesuffix         Removes the suffix if the string ends with it.
25.__add__              Implements the + operator (concatenates strings).


List=append,extend,inser

"""

# %%
name="Sagar Desai"
name
# Out:
# 'Sagar Desai'

# %%
name.capitalize() #only first letter capital
# Out:
# 'Sagar desai'

# %%
name.upper() #all in capital letters
# Out:
# 'SAGAR DESAI'

# %%
name.lower() #all in small case
# Out:
# 'sagar desai'

# %%
name.title() #every words inital capital
# Out:
# 'Sagar Desai'

# %%
name.count("a") #count number of a in variable name
# Out:
# 3

# %%
name.casefold() #name.casefold() चा उपयोग स्ट्रिंग लोअरकेस करण्यासाठी होतो, पण हे lower() पेक्षा जास्त शक्तिशाली आहे. 
#casefold() म्हणजे स्ट्रिंगमधील सगळी अक्षरे लहान (lowercase) करणे,
#पण हे फक्त इंग्रजीत नाही—जगातील जवळपास सगळ्या भाषांचे खास अक्षरंही नीट convert करते.
# Out:
# 'sagar desai'

# %%
name.encode("utf-8")
# Out:
# b'Sagar Desai'

# %%
name.encode("ascii")
# Out:
# b'Sagar Desai'

# %%
name.endswith("i")  #checks whether the string name ends with the letter "i". It returns True if it does; otherwise, it returns False.
# Out:
# True

# %%
name.startswith("s")
# Out:
# False

# %%
name.startswith("S") #checks whether the string name starts with the letter "S". It returns True if it does; otherwise, it returns False.
# Out:
# True

# %%
name.find("g") #to find index number of any letter in string
# Out:
# 2

# %%
name.index("e") #to find index number of any letter in string
# Out:
# 7

# %%
name.isalnum() #
# Out:
# False

# %%
name1
# Out:
# 'King'

# %%
name1.isalnum()   #जर name या व्हेरिएबलमधील स्ट्रिंगमध्ये फक्त अक्षरे आणि अंक असतील, तर name.isalnum() हे True देईल, अन्यथा ते False देईल.
# Out:
# True

# %%
"""Examples for ClarityString 
Valueisalnum() ResultReason
"SagarDesai"     True                    Contains only letters.
"Sagar123"       True                    Contains letters and numbers.
"12345"          True                    Contains only numbers.
"Sagar Desai"    False                   Contains a space.
"Sagar_Desai"    False                   Contains an underscore (_).
""(Empty string) False                   Cannot be empty.
"""

# %%
name.isalpha() #name.isalpha() हे तपासते की स्ट्रिंगमध्ये केवळ अक्षरे (A-Z, a-z) आहेत की नाही.
# Out:
# False

# %%
name1.isalpha()
# Out:
# True

# %%
name.isascii() #isascii() मेथड हे तपासते की स्ट्रिंगमधील प्रत्येक कॅरेक्टर (अक्षर/चिन्ह) हा ASCII कॅरेक्टर सेटचा भाग आहे की नाही. ASCII म्हणजे American Standard Code for Information Interchange. हा सर्वात जुना आणि सर्वात मूलभूत कॅरेक्टर सेट आहे.
# Out:
# True

# %%
name.swapcase()  #swapcase() मेथड स्ट्रिंगमधील प्रत्येक इंग्रजी अक्षराची केस (case) बदलते.
# Out:
# 'sAGAR dESAI'

# %%
name.strip() #strip() मेथड ही स्ट्रिंगच्या सुरुवातीला आणि शेवटी असलेले सर्व Whitespace (मोकळ्या जागा) काढून टाकते.
# Out:
# 'Sagar Desai'

# %%
name2= " Sparsh  "

# %%
name2.strip()
# Out:
# 'Sparsh'

# %%
name.islower() #islower() मेथड हे तपासते की स्ट्रिंगमधील सर्व अक्षरे (Letters) स्मॉल केस (lowercase) मध्ये आहेत की नाहीत.
# Out:
# False

# %%
name.isupper() #isuppe() मेथड हे तपासते की स्ट्रिंगमधील सर्व अक्षरे (Letters) Capital केस (uppercase) मध्ये आहेत की नाहीत.
# Out:
# False

# %%
name.join(name2.strip())
# Out:
# 'SSagar DesaipSagar DesaiaSagar DesairSagar DesaisSagar Desaih'

# %%
name.split()  #name.split() ही Python अभिव्यक्ती स्ट्रिंगमधील Whitespace (मोकळ्या जागा) वापरून त्या स्ट्रिंगचे तुकडे करते आणि त्या तुकड्यांची एक लिस्ट (list) परत करते.
# Out:
# ['Sagar', 'Desai']

# %%
name2.partition("a") #It will split the string with give string"s"
# Out:
# ('Sp', 'a', 'rsh,Desai')

# %%
name.replace("D","d") # to replace the string value
# Out:
# 'Sagar desai'

# %%
name.removeprefix("S") #to reomove prefix
# Out:
# 'agar Desai'

# %%
name.removesuffix("a ") #to remove suffix
# Out:
# 'Sagar Desai'

# %%
name.__contains__("g") #to check if the string element contains or not
# Out:
# True

# %%
name.__len__() #to  check length
# Out:
# 11

# %%
name
# Out:
# 'Sagar Desai'

# %%
name4=name.__add__(" SD") #Immutability: Even though the result is a combined string, the original name variable ("Sagar Desai") is not changed. Python creates a completely new string object ("Sagar Desai SD") in memory.

# %%
name4
# Out:
# 'Sagar Desai SD'

# %%
name.__sizeof__() #या व्हेरिएबलमध्ये साठवलेल्या स्ट्रिंग ऑब्जेक्टचा (String Object) मेमरीमध्ये किती बाइट्स (bytes) व्यापला आहे, हे दर्शवते.
# Out:
# 52

# %% [markdown]
# # 2. List -(Mutable)

# %%
lst=[31,42,63,94]
lst
# Out:
# [31, 42, 63, 94]

# %%
lst.__reversed__()
lst
# Out:
# [31, 42, 63, 94]

# %%
list(lst.__reversed__())   #
# Out:
# [94, 63, 42, 31]

# %%
lst.append(29) #To add record in list
lst
# Out:
# [31, 42, 63, 94, 29]

# %%
lst.remove(29)  #to remove specific record from the list
lst
# Out:
# [31, 42, 63, 94]

# %%
lst.clear()   #to clear the list/all records will be deleted

# %%
lst
# Out:
# [31, 42, 63, 94]

# %%
lst.__sizeof__() #To check used storage in bytes
# Out:
# 72

# %%
new_lst = lst.copy() 
new_lst
# Out:
# [31, 42, 63, 94]

# %%
print(id(lst))  #to check location
# Out:
# 2097961122304

# %%
print(id(new_lst))
# Out:
# 2097962555712

# %%
lst.count(42) #to count no of matching records in ()
# Out:
# 1

# %%
lst.extend(new_lst) #to add new_lst in old lst
lst
# Out:
# [31, 42, 63, 94, 31, 42, 63, 94, 31, 42, 63, 94]

# %%
lst
# Out:
# [31, 42, 63, 94]

# %%
lst.index(63)  #to check index number
# Out:
# 2

# %%
lst.insert(2,11) #Kontya index la konti value add krychi ahe tyasathi(2 arguments req) index number, value
lst
# Out:
# [31, 42, 11, 11, 63, 94]

# %%
lst #re reran lst from line 1
# Out:
# [31, 42, 63, 94]

# %%
lst.pop() #lst.pop() ही मेथड लिस्टमधील घटक काढण्यासाठी (remove) आणि तो काढलेला घटक परत करण्यासाठी (return) वापरली जाते.
          #जर तुम्ही कंसात (Parentheses) कोणताही इंडेक्स दिला नाही, तर pop() मेथड लिस्टच्या शेवटी असलेला घटक (Last Element) काढते.
# Out:
# 94

# %%
lst
# Out:
# [31, 42, 63]

# %%
lst.pop(1) #tried with index number
# Out:
# 42

# %%
lst
# Out:
# [31, 63]

# %%
lst.sort()  #lst.sort() ही मेथड लिस्टच्या घटकांना चढत्या क्रमाने (Ascending Order) किंवा उतरत्या क्रमाने (Descending Order) लावण्यासाठी वापरली जाते.

# %%
lst
# Out:
# [31, 42, 63, 94]

# %%
lst.sort(reverse=True) # उतरत्या क्रमाने लावेल
lst
# Out:
# [94, 63, 42, 31]

# %%
lst1=[9,87,30]
lst1
# Out:
# [9, 87, 30]

# %%
lst.__add__(lst1) #__add__ मेथड: ही मेथड लिस्टसाठी + ऑपरेटर चे कार्य करते, म्हणजेच दोन लिस्ट एकत्र जोडते (Concatenation).
# Out:
# [94, 63, 42, 31, 9, 87, 30]

# %%
lst.sort(reverse=True)
lst
# Out:
# [94, 63, 42, 31]

# %%
lst.__len__() #to check the length
# Out:
# 4

# %% [markdown]
# # 3. Touple -(Immutable)

# %%
tpl = (67,23,32,53,64,86)

# %%
tpl
# Out:
# (67, 23, 32, 53, 64, 86)

# %%
tpl[-1]
tpl[0]
# Out:
# 67

# %%
tpl.count(23)
# Out:
# 1

# %%
tpl.index(53)
# Out:
# 3

# %%
tpl2=(55,99)
tpl2
# Out:
# (55, 99)

# %%
tpl.__add__(tpl2)
# Out:
# (67, 23, 32, 53, 64, 86, 55, 99)

# %%
tpl.__contains__(53)
# Out:
# True

# %%
tpl.__len__()
# Out:
# 6

# %%
tpl.index(86)
# Out:
# 5

# %%
tpl.__sizeof__()
# Out:
# 72

# %%
tpl.__repr__() #ही मेथड टपलला स्ट्रिंगमध्ये रूपांतरित करते, पण कंसासह आणि घटकांसह
# Out:
# '(67, 23, 32, 53, 64, 86)'

# %% [markdown]
# # 4. Set -(Mutable)

# %%
st = {21,141,42,423,97}
st
# Out:
# {21, 42, 97, 141, 423}

# %%
type(set)
# Out:
# set

# %%
set.add(11)

# %%
set
# Out:
# {11, 21, 42, 97, 141, 423}

# %%
set1 ={29,308,530,42}
set1
# Out:
# {29, 42, 308, 530}

# %%
set.difference(set1) #It remove matching record and keep all records from first set
# Out:
# {11, 21, 97, 141, 423}

# %%
set
# Out:
# set

# %%
set
# Out:
# {21, 42, 97, 141, 423}

# %%
set.clear()
set
# Out:
# set()

# %%
set
# Out:
# {21, 42, 97, 141, 423}

# %%
set.remove(97)

# %%
set
# Out:
# {21, 42, 141, 423}

# %% [markdown]
# # Dictionary

# %%
dict1 = {"Name": "Sagar", "Marks": 43}
dict1
# Out:
# {'Name': 'Sagar', 'Marks': 43}

# %%
dict1["Marks"]
# Out:
# 43

# %%
dict1["Name"]
# Out:
# 'Sagar'

# %%
dict1["City"] = "Kolhapur"
dict1
# Out:
# {'Name': 'Sagar', 'Marks': 43, 'City': 'Kolhapur'}

# %%
dict1["Marks"] = 90
dict1
# Out:
# {'Name': 'Sagar', 'Marks': 90, 'City': 'Kolhapur'}

# %%
dict1.pop("Marks")
dict1
# Out:
# {'Name': 'Sagar', 'City': 'Kolhapur'}

# %%
dict1.popitem() #remove last inserted pair
dict1
# Out:
# {'Name': 'Sagar'}

# %%
"Name" in dict1 #check if "Name" is exits or not
# Out:
# True

# %%
dict1.get("Marks")
dict1
# Out:
# {'Name': 'Sagar'}

# %%
dict1.get("Age", 0) 
dict1
# Out:
# {'Name': 'Sagar'}

# %%
dict1.keys()      
dict1.values()    
dict1.items()
# Out:
# dict_items([('Name', 'Sagar')])

# %%
dict1.clear()
dict1
# Out:
# {}
