# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
input1= int(input())
if input1 > 0:
        print("Number is Positive")
else:
        print("Number is Negative")
# Out:
# Number is Negative

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
input2= int(input())
if input2 % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Number is Odd

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
age=int(input())
if age >=18:
    print("You are eligible for Vote")
else:
    print("You are not eligible for Vote")
# Out:
# You are not eligible for Vote

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
number=int(input())
if number > 100:
    print("Number is greater than 100")
else:
    print("Number is less than 100")
# Out:
# Number is greater than 100

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
age1=int(input())
if age1 >18:
    print("Adult")
else:
    print("Child")
# Out:
# Adult

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
a=30
b=30
if a==b:
    print("Numbers are equal")
else:
    print("Numbers are not iqual")
# Out:
# Numbers are equal

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
input3=int(input())
if input3 % 5==0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Number is divisible by 5

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
input4=input()
if input4== "hello":
    print("Its hello")
else:
    print("Its not hello")
# Out:
# Its hello

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
a=45
b=31
if a>b:
    print(f"{a} is larger than {b}")
else:
    print(f"{b} is larger than {a}")
# Out:
# 45 is larger than 31

# %% [markdown]
# ### 10. Check if a number is negative

# %%
a= -4
if a < 0:
    print("Negative")
else:
    print("Positive")
# Out:
# Negative

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
input5=int(input())
if input5 == 0:
    print("Zero")
elif input5 > 0:
    print("Positive Number")
elif input5 <0:
    print("Negative Number")
# Out:
# Positive Number

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
input6=int(input())
if input6 % 4 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
input7=input().lower()

if input7 == "a" or input7 == "e" or input7 == "i" or input7 == "o" or input7 == "u":
    print("Its a vowel")
else:
    print("Its consonant")
# Out:
# Its consonant

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
a=23
b=24
c=26

print("Max:",max(a,b,c))
# Out:
# Max: 26

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
input9=input()
if len(input9) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Strong Password

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
a =3
print(a <50 and a >10)
# Out:
# False

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
marks = int(input())
if marks >= 80:
    print("A")
elif marks >=60 and marks < 80:
    print("B")
elif marks >=40 and marks < 60:
    print("C")
elif marks <35:
    print("D")
# Out:
# D

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
a= 10
if a%2 ==0 and a%3==0:
    print("No is Divisible by both 2 and 3")
else:
    print("Cant divide by 2 and 3")
# Out:
# Cant divide by 2 and 3

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
age2=int(input())
if age2 >= 60:
    print("Senior")
elif age2 <60 and age2>=18:
    print("Adult")
elif age2 < 18 and age2>=10:
    print("Teen")
elif age2 <10:
    print("Child")
# Out:
# Senior

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
a=input()
if a==a.lower():
    print("Lowercase")
elif  a==a.upper():
    print("Uppercase")

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
a=103
if a % 10 == 0:
    print("No is multiple of 10")
else:
    print("Not multiple of 10")
# Out:
# Not multiple of 10

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
a=22
b=22
if a>b:
    print("Greater")
elif a<b:
    print("Smaller")
elif a==b:
    print("Equal")
# Out:
# Equal

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %%
a=34
b=32
c=33
if a==b==c:
    print("Equilateral")
elif a==b or a==c or b==c:
    print("Isosceles")
elif a!=b!=c:
    print("Scalene")
# Out:
# Scalene

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
a="Python Developer"
if a.__contains__("Python"):
    print("Python")
# Out:
# Python

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
lst=[32,42,44,54,52,52]
len(lst)>5
# Out:
# True

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
temp=29
if temp > 30:
    print("Hot")
elif temp < 15:
    print("Cold")
else:
    print("Warm")
# Out:
# Warm

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks = 32
if marks >=40:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
a=32

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
a= "Banana"
if a.startswith("a"or "i" or "o" or"u" or "e"):
    print(": Starts with Vowel")
elif a.startswith("A"or "I" or "O" or"U" or "E"):
    print(": Starts with Vowel")
else:
    print("Consonant")
# Out:
# Consonant

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
a=101

if a <=100 and a>=1:
    print("In Range")
else:
    print("Out of Range")
# Out:
# Out of Range

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %%
a=1
if a%2 !=0 and a:
    print("Prime Number")
else:
    print("Composite Number")
# Out:
# Prime Number

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
num = 31

if int(str(num)[-1]) % 2 == 0:
    print("Last digit of number is Even")
else:
    print("Last digit of number is Odd")
# Out:
# Last digit of number is Odd

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
a="Sagar"
if

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
a=100
b=40
c=40
if a+b+c==180:
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Valid Triangle

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
str1 = "listen"
str2 = "silent"

if sorted(str1) == sorted(str2):
    print("The strings are anagrams")
else:
    print("The strings are not anagrams")
# Out:
# The strings are anagrams

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %%
# a=int(input())
# b=int(input())
# c=int(input())
# if (a+b+c) >180 or (a+b+c) !=180 :
#     print("Not a valid triangle")
# elif a>90 or b>90 or c>90:
#     print("Obtuse Angle Triangle")
# elif a<90 and b<90 and c<90:
#     print("Acute Angle Triangle")
# elif  a==90 or b==90 or c==90:
#     print("Right Angle Triangle")


A = 2
B = 5
C = 4

# Step 1: Sort sides so that c is the largest
sides = sorted([A, B, C])
x, y, z = sides  # z is the largest side

# Step 2: Use square rule
if x**2 + y**2 == z**2:
    print("Right Triangle")
elif x**2 + y**2 > z**2:
    print("Acute Triangle")
else:
    print("Obtuse Triangle")
# Out:
# Obtuse Triangle

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %%
a = madam 
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a = madam
#       2 print(a)
#
# NameError: name 'madam' is not defined

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %%
a="Aradhya"
if a.lower()[0]==a[6]:
    print("same")
# Out:
# same

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
a=432
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 a=432
# ----> 2 a(d)
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
a="Sparsh"
b="Sachin"
if len(a)>=len(b):
    print("a is larger")
else:
    print("b is larger")
# Out:
# a is larger

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %%
lst=[31,321,33,42,52,321]

if len(lst)!=len(set(lst)):
    print("Contain Duplicates")
else:
    print("There are no Duplicates")
# Out:
# Contain Duplicates

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
a=0
b=2332
if a==0 or b==0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
pswd=input()
type(pswd)
# Out:
# str

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
a=312
a//100
# Out:
# 3

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
a=int(input("Enter any number:"))
b=int(input("Enter any number:"))

if abs(a-b)<10:
    print(f"Absolute difference between {a} and {b} is less than 10 : {abs(a-b)}")
else:
    print(f"Absolute difference between {a} and {b} is not less than 10: {abs(a-b)}")
# Out:
# Absolute difference between 21 and 32 is not less than 10: 11

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
a=input()

if a.isdigit

# %%
a= int(input("Enter any number: "))
if isinstance(a,int):
    print(f"{a} variable is an integer")
else:
    print(f"{a} variable is not an integer")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 a= int(input("Enter any number: "))
#       2 if isinstance(a,int):
#       3     print(f"{a} variable is an integer")
#
# ValueError: invalid literal for int() with base 10: 'f'

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
a=83
if isinstance(a,str):
    print("Its a string")
else:
    print("Its not string")
# Out:
# Its not string

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
a=32.4
if type(a)==float:
    print("Float Value Found")
# Out:
# Float Value Found

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
lst=[2,32,32,44]
if type(lst)==list:
    print(len(lst))
# Out:
# 4

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
a=(23,234,42)
if type(a) ==tuple:
    print(a[0])
# Out:
# 23

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
a={"name":"Sagar","Surname":"Desai"}
if type(a)==dict:
    print(a.keys())
# Out:
# dict_keys(['name', 'Surname'])

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
a={31,32}
if type(a)==set:
    print(a)
# Out:
# {32, 31}

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
a=False
if type(a) == bool:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.
